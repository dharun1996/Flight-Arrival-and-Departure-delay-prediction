# %%
pip install WorldWeatherPy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from WorldWeatherPy import DetermineListOfAttributes
from WorldWeatherPy import HistoricalLocationWeather
from WorldWeatherPy import RetrieveByAttribute

# %%
import pandas as pd

# %%
IAD = HistoricalLocationWeather('0c9027ea993e40498ff210917211104', '20166', '2016-01-01', '2020-12-31', 1).retrieve_hist_data()
# Out:
# Retrieving weather data for 20166
#
#
# Retrieving data for 20166 from: 2016-01-01 to: 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.513447
# Retrieving data for 20166 from: 2016-02-01 to: 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.764029
# Retrieving data for 20166 from: 2016-03-01 to: 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.224748
# Retrieving data for 20166 from: 2016-04-01 to: 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:09.603079
# Retrieving data for 20166 from: 2016-05-01 to: 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.459704
# Retrieving data for 20166 from: 2016-06-01 to: 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:14.751635
# Retrieving data for 20166 from: 2016-07-01 to: 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:17.166609
# Retrieving data for 20166 from: 2016-08-01 to: 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.444247
# Retrieving data for 20166 from: 2016-09-01 to: 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:22.025425
# ...

# %%
IAD.head(10)
# Out:
#                     maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# date_time
# 2016-01-01 00:00:00        6        2          0.0     8.7       2
# 2016-01-01 01:00:00        6        2          0.0     8.7       2
# 2016-01-01 02:00:00        6        2          0.0     8.7       2
# 2016-01-01 03:00:00        6        2          0.0     8.7       2
# 2016-01-01 04:00:00        6        2          0.0     8.7       2
# 2016-01-01 05:00:00        6        2          0.0     8.7       2
# 2016-01-01 06:00:00        6        2          0.0     8.7       2
# 2016-01-01 07:00:00        6        2          0.0     8.7       2
# 2016-01-01 08:00:00        6        2          0.0     8.7       2
# 2016-01-01 09:00:00        6        2          0.0     8.7       2
#
#                     moon_illumination  moonrise   moonset   sunrise    sunset  \
# date_time
# 2016-01-01 00:00:00                50  12:23 AM  12:42 PM  08:28 AM  05:58 PM
# ...

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(IAD)

# %%
#IAD.to_csv("IAD_new.csv", index = True)

# %%
TPA = HistoricalLocationWeather('0c9027ea993e40498ff210917211104', '33607', '2016-01-01', '2020-12-31', 1).retrieve_hist_data()
# Out:
# Retrieving weather data for 33607
#
#
# Retrieving data for 33607 from: 2016-01-01 to: 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.567045
# Retrieving data for 33607 from: 2016-02-01 to: 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:05.023775
# Retrieving data for 33607 from: 2016-03-01 to: 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.718631
# Retrieving data for 33607 from: 2016-04-01 to: 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.467622
# Retrieving data for 33607 from: 2016-05-01 to: 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.989172
# Retrieving data for 33607 from: 2016-06-01 to: 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:16.416279
# Retrieving data for 33607 from: 2016-07-01 to: 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.016637
# Retrieving data for 33607 from: 2016-08-01 to: 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:21.462235
# Retrieving data for 33607 from: 2016-09-01 to: 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:24.570848
# ...

# %%
TPA.head(10)
# Out:
#                     maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# date_time
# 2016-01-01 00:00:00       26       21          0.0    10.3       6
# 2016-01-01 01:00:00       26       21          0.0    10.3       6
# 2016-01-01 02:00:00       26       21          0.0    10.3       6
# 2016-01-01 03:00:00       26       21          0.0    10.3       6
# 2016-01-01 04:00:00       26       21          0.0    10.3       6
# 2016-01-01 05:00:00       26       21          0.0    10.3       6
# 2016-01-01 06:00:00       26       21          0.0    10.3       6
# 2016-01-01 07:00:00       26       21          0.0    10.3       6
# 2016-01-01 08:00:00       26       21          0.0    10.3       6
# 2016-01-01 09:00:00       26       21          0.0    10.3       6
#
#                     moon_illumination  moonrise   moonset   sunrise    sunset  \
# date_time
# 2016-01-01 00:00:00                50  12:45 AM  01:04 PM  08:21 AM  06:46 PM
# ...

# %%
#TPA.to_csv("TPA_new.csv", index = True)

# %%
RDU = HistoricalLocationWeather('0c9027ea993e40498ff210917211104', '27560', '2016-01-01', '2020-12-31', 1).retrieve_hist_data()
# Out:
# Retrieving weather data for 27560
#
#
# Retrieving data for 27560 from: 2016-01-01 to: 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.742239
# Retrieving data for 27560 from: 2016-02-01 to: 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:05.173594
# Retrieving data for 27560 from: 2016-03-01 to: 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.594112
# Retrieving data for 27560 from: 2016-04-01 to: 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:09.984707
# Retrieving data for 27560 from: 2016-05-01 to: 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.744341
# Retrieving data for 27560 from: 2016-06-01 to: 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:15.104616
# Retrieving data for 27560 from: 2016-07-01 to: 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:17.414375
# Retrieving data for 27560 from: 2016-08-01 to: 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.830957
# Retrieving data for 27560 from: 2016-09-01 to: 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:22.208914
# ...

# %%
RDU.head(10)
# Out:
#                     maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# date_time
# 2016-01-01 00:00:00       11        6          0.0     8.3       3
# 2016-01-01 01:00:00       11        6          0.0     8.3       3
# 2016-01-01 02:00:00       11        6          0.0     8.3       3
# 2016-01-01 03:00:00       11        6          0.0     8.3       3
# 2016-01-01 04:00:00       11        6          0.0     8.3       3
# 2016-01-01 05:00:00       11        6          0.0     8.3       3
# 2016-01-01 06:00:00       11        6          0.0     8.3       3
# 2016-01-01 07:00:00       11        6          0.0     8.3       3
# 2016-01-01 08:00:00       11        6          0.0     8.3       3
# 2016-01-01 09:00:00       11        6          0.0     8.3       3
#
#                     moon_illumination  moonrise   moonset   sunrise    sunset  \
# date_time
# 2016-01-01 00:00:00                50  12:29 AM  12:48 PM  08:25 AM  06:12 PM
# ...

# %%
RDU.to_csv("RDU.csv", index = False)
