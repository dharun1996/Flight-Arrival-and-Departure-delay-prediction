# %%
#pip install WorldWeatherPy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from WorldWeatherPy import DetermineListOfAttributes
from WorldWeatherPy import HistoricalLocationWeather
from WorldWeatherPy import RetrieveByAttribute

# %%
import pandas as pd

# %%
attributes = DetermineListOfAttributes('0c9027ea993e40498ff210917211104', True).retrieve_list_of_options()
# Out:
# Retrieving attribute list...
# List of available weather attributes: ['sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination', 'time', 'tempC', 'tempF', 'windspeedMiles', 'windspeedKmph', 'winddirDegree', 'winddir16Point', 'weatherCode', 'weatherIconUrl', 'weatherDesc', 'precipMM', 'precipInches', 'humidity', 'visibility', 'visibilityMiles', 'pressure', 'pressureInches', 'cloudcover', 'HeatIndexC', 'HeatIndexF', 'DewPointC', 'DewPointF', 'WindChillC', 'WindChillF', 'WindGustMiles', 'WindGustKmph', 'FeelsLikeC', 'FeelsLikeF', 'uvIndex']

# %%
ord1 = HistoricalLocationWeather('0c9027ea993e40498ff210917211104', '60666', '2016-01-01', '2020-12-31', 1).retrieve_hist_data()
# Out:
# Retrieving weather data for 60666
#
#
# Retrieving data for 60666 from: 2016-01-01 to: 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.711392
# Retrieving data for 60666 from: 2016-02-01 to: 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:06.830551
# Retrieving data for 60666 from: 2016-03-01 to: 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.878086
# Retrieving data for 60666 from: 2016-04-01 to: 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:14.395816
# Retrieving data for 60666 from: 2016-05-01 to: 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:17.850827
# Retrieving data for 60666 from: 2016-06-01 to: 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:21.066034
# Retrieving data for 60666 from: 2016-07-01 to: 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:24.472311
# Retrieving data for 60666 from: 2016-08-01 to: 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.746497
# Retrieving data for 60666 from: 2016-09-01 to: 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:30.852185
# ...

# %%
ord1
# Out:
#                     maxtempC mintempC totalSnow_cm sunHour uvIndex  \
# date_time
# 2016-01-01 00:00:00       -3       -7          0.0     5.2       2
# 2016-01-01 01:00:00       -3       -7          0.0     5.2       2
# 2016-01-01 02:00:00       -3       -7          0.0     5.2       2
# 2016-01-01 03:00:00       -3       -7          0.0     5.2       2
# 2016-01-01 04:00:00       -3       -7          0.0     5.2       2
# ...                      ...      ...          ...     ...     ...
# 2020-12-31 19:00:00       -3       -9          0.0     6.9       1
# 2020-12-31 20:00:00       -3       -9          0.0     6.9       1
# 2020-12-31 21:00:00       -3       -9          0.0     6.9       1
# 2020-12-31 22:00:00       -3       -9          0.0     6.9       1
# 2020-12-31 23:00:00       -3       -9          0.0     6.9       1
#
#                     moon_illumination  moonrise   moonset   sunrise    sunset  \
# date_time
# ...

# %%
ord1.to_csv('JFK.csv')

# %%
ord1 = HistoricalLocationWeather('0c9027ea993e40498ff210917211104', '11430', '2016-01-01', '2020-12-31', 1).retrieve_hist_data()
# Out:
# Retrieving weather data for 11430
#
#
# Retrieving data for 11430 from: 2016-01-01 to: 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.300270
# Retrieving data for 11430 from: 2016-02-01 to: 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:06.876374
# Retrieving data for 11430 from: 2016-03-01 to: 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.091940
# Retrieving data for 11430 from: 2016-04-01 to: 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:14.475528
# Retrieving data for 11430 from: 2016-05-01 to: 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:18.036490
# Retrieving data for 11430 from: 2016-06-01 to: 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:21.099327
# Retrieving data for 11430 from: 2016-07-01 to: 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:24.426029
# Retrieving data for 11430 from: 2016-08-01 to: 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.787437
# Retrieving data for 11430 from: 2016-09-01 to: 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:30.828287
# ...

# %%
LGA = HistoricalLocationWeather('0c9027ea993e40498ff210917211104', '11371', '2016-01-01', '2020-12-31', 1).retrieve_hist_data()
# Out:
# Retrieving weather data for 11371
#
#
# Retrieving data for 11371 from: 2016-01-01 to: 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.896552
# Retrieving data for 11371 from: 2016-02-01 to: 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:07.306216
# Retrieving data for 11371 from: 2016-03-01 to: 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.288123
# Retrieving data for 11371 from: 2016-04-01 to: 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:14.982829
# Retrieving data for 11371 from: 2016-05-01 to: 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.046008
# Retrieving data for 11371 from: 2016-06-01 to: 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:23.108906
# Retrieving data for 11371 from: 2016-07-01 to: 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.153060
# Retrieving data for 11371 from: 2016-08-01 to: 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:30.902063
# Retrieving data for 11371 from: 2016-09-01 to: 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:34.839819
# ...

# %%
LGA.to_csv('LGA.csv')

# %%
ATL = HistoricalLocationWeather('0c9027ea993e40498ff210917211104', '30320', '2016-01-01', '2020-12-31', 1).retrieve_hist_data()
# Out:
# Retrieving weather data for 30320
#
#
# Retrieving data for 30320 from: 2016-01-01 to: 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.774100
# Retrieving data for 30320 from: 2016-02-01 to: 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:05.496314
# Retrieving data for 30320 from: 2016-03-01 to: 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.246777
# Retrieving data for 30320 from: 2016-04-01 to: 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:11.082604
# Retrieving data for 30320 from: 2016-05-01 to: 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:14.003199
# Retrieving data for 30320 from: 2016-06-01 to: 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:16.725485
# Retrieving data for 30320 from: 2016-07-01 to: 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.446848
# Retrieving data for 30320 from: 2016-08-01 to: 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:22.118296
# Retrieving data for 30320 from: 2016-09-01 to: 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:25.088838
# ...

# %%
ATL.to_csv('ATL.csv')
