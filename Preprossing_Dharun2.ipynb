# %%
import pandas as pd
import numpy as np

# %%
we = pd.read_csv(r'C:\Users\dharu\Documents\Studies\Q7\DS672\Data\Mer\w.csv')

# %%
ar = pd.read_csv(r'C:\Users\dharu\Documents\Studies\Q7\DS672\Data\Detailed_Statistics_Arrivals_Combined.csv')
# Out:
# C:\Users\dharu\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (2,7,8,9,11,12,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ar
# Out:
#         Carrier Code Date (MM/DD/YYYY) Flight Number Tail Number  \
# 0                 AA          1/1/2016           232      N023AA
# 1                 AA          1/1/2016           604      N542UW
# 2                 AA          1/1/2016           610      N580UW
# 3                 AA          1/1/2016           612      N640AW
# 4                 AA          1/1/2016           614      N663AW
# ...              ...               ...           ...         ...
# 4245606           UA          12/31/20          2002      N489UA
# 4245607           UA          12/31/20          2067      N38268
# 4245608           UA          12/31/20          2137      N37252
# 4245609           UA          12/31/20          2145      N26226
# 4245610           UA          12/31/20          2158      N37456
#
#         Origin Airport Scheduled Arrival Time Actual Arrival Time  \
# 0                  DFW                  18:36               19:03
# ...

# %%
lst = ['ORD', 'JFK', 'ATL', 'IAH', 'LAS', 'LAX', 'SFO', 'IAD', 'TPA', 'RDU','LGA']
f_df = ar[ar['Origin Airport'].isin(lst)]

# %%
f_df.describe
# Out:
# <bound method NDFrame.describe of         Carrier Code Date (MM/DD/YYYY) Flight Number Tail Number  \
# 9                 AA          1/1/2016          1116      N005AA
# 11                AA          1/1/2016          1249      N027AA
# 20                AA          1/1/2016          2319      N4XBAA
# 23                AA          1/1/2016          2513      N020AA
# 34                AA          1/1/2017           909      N3FVAA
# ...              ...               ...           ...         ...
# 4245604           UA          12/31/20          1444      N75425
# 4245605           UA          12/31/20          1538      N69818
# 4245606           UA          12/31/20          2002      N489UA
# 4245607           UA          12/31/20          2067      N38268
# 4245610           UA          12/31/20          2158      N37456
#
#         Origin Airport Scheduled Arrival Time Actual Arrival Time  \
# 9                  LAX                   6:13                5:57
# ...

# %%
f_df.to_csv('ar.csv')

# %%
arr = pd.read_csv(r'C:\Users\dharu\Documents\Studies\Q7\DS672\Data\arr.csv')

# %%
arr
# Out:
#               V1 CarrierCode DateMMDDYYYY  FlightNumber TailNumber  \
# 0              9          AA     1/1/2016          1116     N005AA
# 1             11          AA     1/1/2016          1249     N027AA
# 2             20          AA     1/1/2016          2319     N4XBAA
# 3             23          AA     1/1/2016          2513     N020AA
# 4             34          AA     1/1/2017           909     N3FVAA
# ...          ...         ...          ...           ...        ...
# 1288197  4245604          UA   12/31/2020          1444     N75425
# 1288198  4245605          UA   12/31/2020          1538     N69818
# 1288199  4245606          UA   12/31/2020          2002     N489UA
# 1288200  4245607          UA   12/31/2020          2067     N38268
# 1288201  4245610          UA   12/31/2020          2158     N37456
#
#         OriginAirport ScheduledArrivalTime ActualArrivalTime  \
# 0                 LAX              6:13:00           5:57:00
# ...

# %%
arr = arr.rename(columns = {'DateMMDDYYYY':'date','ArrTime':'time','zipcode':'city'} )

# %%
arr
# Out:
#               V1 CarrierCode        date  FlightNumber TailNumber  \
# 0              9          AA    1/1/2016          1116     N005AA
# 1             11          AA    1/1/2016          1249     N027AA
# 2             20          AA    1/1/2016          2319     N4XBAA
# 3             23          AA    1/1/2016          2513     N020AA
# 4             34          AA    1/1/2017           909     N3FVAA
# ...          ...         ...         ...           ...        ...
# 1288197  4245604          UA  12/31/2020          1444     N75425
# 1288198  4245605          UA  12/31/2020          1538     N69818
# 1288199  4245606          UA  12/31/2020          2002     N489UA
# 1288200  4245607          UA  12/31/2020          2067     N38268
# 1288201  4245610          UA  12/31/2020          2158     N37456
#
#         OriginAirport ScheduledArrivalTime ActualArrivalTime  \
# 0                 LAX              6:13:00           5:57:00
# ...

# %%
print (arr.dtypes)
print (we.dtypes)
# Out:
# V1                                             int64
# CarrierCode                                   object
# date                                  datetime64[ns]
# FlightNumber                                   int64
# TailNumber                                    object
# OriginAirport                                 object
# ScheduledArrivalTime                          object
# ActualArrivalTime                             object
# ScheduledElapsedTimeMinutes                    int64
# ActualElapsedTimeMinutes                       int64
# ArrivalDelayMinutes                            int64
# WheelsonTime                                  object
# TaxiIntimeMinutes                              int64
# DelayCarrierMinutes                            int64
# DelayWeatherMinutes                            int64
# DelayNationalAviationSystemMinutes             int64
# DelaySecurityMinutes                           int64
# DelayLateAircraftArrivalMinutes                int64
# ...

# %%
a = arr['date']
a =  pd.to_datetime(a,format = '%m/%d/%Y')
arr['date'] = a
b = we['date']
b =  pd.to_datetime(b,format = '%m/%d/%y')
we['date'] = b

# %%
result1 = pd.merge( arr, we, on = ["city", "date","time"])

# %%
result1
# Out:
#               V1 CarrierCode       date  FlightNumber TailNumber  \
# 0              9          AA 2016-01-01          1116     N005AA
# 1          57876          DL 2016-01-01          1098     N127DL
# 2          57917          DL 2016-01-01          1254     N551NW
# 3          57943          DL 2016-01-01          1354     N1611B
# 4        1106367          NK 2016-01-01           806     N506NK
# ...          ...         ...        ...           ...        ...
# 1288197  4245586          UA 2019-12-31          1930     N77530
# 1288198  4245588          UA 2019-12-31          2002     N445UA
# 1288199  4245592          UA 2019-12-31          2389     N38403
# 1288200  4245595          UA 2020-12-31           360     N832UA
# 1288201  4245604          UA 2020-12-31          1444     N75425
#
#         OriginAirport ScheduledArrivalTime ActualArrivalTime  \
# 0                 LAX              6:13:00           5:57:00
# ...

# %%
result1.to_csv('arrival_merged.csv')
